# %% [markdown]
# <a href="https://colab.research.google.com/github/adityabansal21/ExMart/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
uvicorn app.main:app --reload --host 0.0.0.0 --port 8000
# Out:
#   File "/tmp/ipython-input-2573873486.py", line 1
#     uvicorn app.main:app --reload --host 0.0.0.0 --port 8000
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Task
# Please provide the GitHub repository URL to clone.

# %% [markdown]
# ## Clone Repository
#
# ### Subtask:
# Prompt the user to provide the GitHub repository URL.

# %% [markdown]
# ### Subtask
# Prompt the user to provide the GitHub repository URL.
#
# #### Instructions
# Please provide the GitHub repository URL that you want to clone.

# %% [markdown]
# ## Clone Repository
#
# ### Subtask:
# Obtain the GitHub repository URL from the user to proceed with cloning.

# %% [markdown]
# ### Subtask:
# Obtain the GitHub repository URL from the user to proceed with cloning.
#
# #### Instructions:
# 1. Please provide the full GitHub repository URL (e.g., `https://github.com/user/repo.git`) that you wish to clone.
# 2. Ensure the URL is correct and accessible.
#
# **Please provide the URL in the chat.**

# %% [markdown]
# ## Clone Repository
#
# ### Subtask:
# Clone the provided GitHub repository into the current environment.

# %% [markdown]
# **Reasoning**:
# To clone the GitHub repository, I need to execute a shell command using `!git clone`.

# %%
# !git clone https://github.com/adityabansal21/ExMart.git
# Out:
# Cloning into 'ExMart'...
# fatal: could not read Username for 'https://github.com': No such device or address
